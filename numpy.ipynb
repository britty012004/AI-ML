# %%
import numpy as np
arr = np.ones((2, 4))
print(arr)
# Out:
# [[1. 1. 1. 1.]
#  [1. 1. 1. 1.]]

# %%
np.ones((2, 4))
# Out:
# array([[1., 1., 1., 1.],
#        [1., 1., 1., 1.]])

# %%
np.eye(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
np.arange(0, 10, 2)
# Out:
# array([0, 2, 4, 6, 8])

# %%
np.linspace(0, 1, 5)
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
np.random.rand(3, 2)
# Out:
# array([[0.22537182, 0.62907136],
#        [0.9722968 , 0.16397269],
#        [0.75681717, 0.58533873]])

# %%
np.random.randn(3, 2)
# Out:
# array([[ 1.06704038, -1.1253918 ],
#        [-0.70322759, -0.63765244],
#        [-0.15517116,  0.43882815]])

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])
print(arr.shape)
print(arr.ndim)
print(arr.size)
print(arr.dtype)
# Out:
# (2, 3)
# 2
# 6
# int64

# %%
# 1D Arrays
arr = np.array([1, 2, 3, 4, 5])
arr[0]

arr[1:4]
arr[::2]
# Out:
# array([1, 3, 5])

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])
arr[0, 1]
arr[:, 1]
arr[1, :2]
# Out:
# array([4, 5])

# %%
arr = np.array([1, 2, 3, 4, 5])
mask = arr > 3
arr[mask]
# Out:
# array([4, 5])

# %%
# Reshape
arr = np.arange(6)
arr.reshape(2, 3)

# Concatenation
a = np.array([1, 2])
b = np.array([3, 4])
np.concatenate((a, b))

# Stacking
np.vstack((a, b))
np.hstack((a, b))
# Out:
# array([1, 2, 3, 4])

# %%
arr = np.arange(6)
arr.reshape(2, 3)
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
print(a+b)
# Out:
# [5 7 9]

# %%
print(a*b)
# Out:
# [ 4 10 18]

# %%
print(a-b)
# Out:
# [-3 -3 -3]

# %%
a*b
# Out:
# array([ 4, 10, 18])

# %%
np.sin(a)
# Out:
# array([0.84147098, 0.90929743, 0.14112001])

# %%
A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])
np.dot(A, B)
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
A @ B
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
arr = np.array([1, 2, 3, 4])
arr.sum()
# Out:
# np.int64(10)

# %%
arr.mean()
# Out:
# np.float64(2.5)

# %%
arr.max()
# Out:
# np.int64(4)

# %%
arr.min()
# Out:
# np.int64(1)

# %%
arr.std()
# Out:
# np.float64(1.118033988749895)

# %%
arr = np.array([1, 2, 3, 4, 5])
arr[0]
# Out:
# np.int64(1)

# %%
arr[1:4]
# Out:
# array([2, 3, 4])

# %%
arr[::2]
# Out:
# array([1, 3, 5])

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])
arr[0, 1]
# Out:
# np.int64(2)

# %%
arr[:, 1]
# Out:
# array([2, 5])

# %%
arr[1, :2]
# Out:
# array([4, 5])

# %%
arr = np.array([1, 2, 3, 4, 5])

# %%
mask = arr > 3
arr[mask]
# Out:
# array([4, 5])
